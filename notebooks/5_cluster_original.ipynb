# %%
import sys
import os
import pandas as pd 

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from scripts.clustering.original_space_clustering import KPrototypesEvaluator, FeatureSelector

# %%
df = pd.read_csv(r'C:\Users\jaret\OneDrive\Documents\UFG\TCC\ENEM - final\data\MICRODADOS_RJ_clean_2023.csv')

# %%
selector = FeatureSelector(df)
selector.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
selector.analyze_features()
# Out:
# --- FeatureSelector Initialized ---
# Detected 6 numerical columns: ['CO_MUNICIPIO_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
# Detected 29 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
#
# --- Starting Feature Analysis ---
# Calculating Coefficient of Variation for numerical features...
# Calculating Correlation Matrix for numerical features...
# Calculating Normalized Entropy for categorical features...
# Calculating Normalized Mutual Information for categorical features...

# %% [markdown]
# CV threshold: 0.2

# %%
df = pd.read_csv(r'C:\Users\jaret\OneDrive\Documents\UFG\TCC\ENEM - final\data\MICRODADOS_RJ_clean_2023.csv')
selector = FeatureSelector(df)
selector.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
# Out:
# --- FeatureSelector Initialized ---
# Detected 6 numerical columns: ['CO_MUNICIPIO_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
# Detected 29 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
#        TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA  \
# 49534          17 anos  Masculino      Branca
# 36740          17 anos   Feminino      Branca
# 109614         18 anos  Masculino      Branca
# 40550          18 anos   Feminino      Branca
# 8599           19 anos   Feminino      Branca
# ...                ...        ...         ...
# 12413          18 anos   Feminino      Branca
# 109663         18 anos   Feminino       Preta
# 155122         17 anos  Masculino      Branca
# 120857         18 anos   Feminino      Branca
# 60315          19 anos  Masculino       Parda
#
#                                           TP_ST_CONCLUSAO  NU_NOTA_CN  \
# 49534   Estou cursando e concluirei o Ensino Médio em ...       648.3
# 36740   Estou cursando e concluirei o Ensino Médio apó...       446.4
# 109614  Estou cursando e concluirei o Ensino Médio em ...       548.3
# 40550   Estou cursando e concluirei o Ensino Médio em ...       432.5
# 8599                            Já concluí o Ensino Médio       461.4
# ...                                                   ...         ...
# 12413   Estou cursando e concluirei o Ensino Médio em ...       533.8
# 109663                          Já concluí o Ensino Médio       583.8
# 155122  Estou cursando e concluirei o Ensino Médio em ...       601.9
# 120857  Estou cursando e concluirei o Ensino Médio em ...       499.8
# 60315                           Já concluí o Ensino Médio       572.9
#
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 49534        672.9       507.2       773.0            800.0  Faculdade ou pós
# 36740        515.8       519.1       493.2            800.0       EM completo
# 109614       622.3       590.8       736.4            680.0       EM completo
# 40550        458.1       446.0       345.3            840.0     EF incompleto
# 8599         541.6       550.8       477.8            500.0  Faculdade ou pós
# ...            ...         ...         ...              ...               ...
# 12413        628.6       584.0       621.8            420.0       EM completo
# 109663       635.3       661.0       612.3            700.0     EF incompleto
# 155122       554.2       544.0       773.3            840.0  Faculdade ou pós
# 120857       575.4       605.6       642.8            720.0     EF incompleto
# 60315        574.6       578.5       643.7            800.0     EF incompleto
#
#         ... Q016 Q017 Q018 Q019 Q020 Q021 Q022 Q023 Q024 Q025
# 49534   ...  Sim  Não  Não  Sim  Sim  Não  Sim  Sim  Sim  Sim
# 36740   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Sim  Sim
# 109614  ...  Não  Não  Sim  Sim  Não  Sim  Sim  Não  Sim  Sim
# 40550   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 8599    ...  Não  Não  Não  Sim  Não  Não  Sim  Sim  Sim  Sim
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 12413   ...  Sim  Não  Não  Sim  Não  Não  Sim  Sim  Não  Sim
# 109663  ...  Sim  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 155122  ...  Sim  Não  Não  Sim  Não  Não  Não  Não  Sim  Sim
# 120857  ...  Sim  Não  Sim  Sim  Sim  Sim  Sim  Sim  Não  Sim
# 60315   ...  Sim  Não  Sim  Sim  Não  Não  Sim  Não  Sim  Sim
#
# [1776 rows x 34 columns]

# %%
df_selected = selector.select_features(
    cv_threshold=0.2, 
    correlation_threshold=0.7, 
    entropy_threshold=0.7, 
    mutual_info_threshold=0.5
)
selected_features = df_selected.columns.tolist()
selected_features.append('CO_MUNICIPIO_PROVA')
# Out:
# --- Starting Feature Selection Process ---
#
# Analyzing 5 numerical features...
# Checking for Coefficient of Variation below 0.2...
#   -> Found 3 low-CV columns to drop: ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']
# Checking for Pearson correlations above 0.7...
#   -> No highly correlated column pairs found.
#
# Checking for normalized entropy below 0.7...
#   -> Found 15 low-entropy columns to drop: ['TP_COR_RACA', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025']
# Checking for normalized mutual information above 0.5...
#   -> No high mutual information column pairs found.
#
# Dropping a total of 18 unique columns: ['Q025', 'NU_NOTA_LC', 'Q008', 'Q006', 'Q011', 'NU_NOTA_CH', 'Q022', 'Q023', 'Q009', 'NU_NOTA_CN', 'Q005', 'Q020', 'Q019', 'Q017', 'Q012', 'Q015', 'TP_COR_RACA', 'Q007']
# Feature selection complete.
#
# --- Feature Selection Finished ---

# %%
k_range = range(2,9)
evaluator = KPrototypesEvaluator(
    df=df[selected_features], 
    original_df_full=df,
    k_range=k_range, 
    gamma_list=[2.0],
    random_state=42
)
evaluator.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
evaluator.scale_numerical_features()
# Out:
# Full original dataframe loaded for statistical analysis.
# Detected 3 numerical columns: ['NU_NOTA_MT', 'NU_NOTA_REDACAO', 'CO_MUNICIPIO_PROVA']
# Detected 14 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q010', 'Q013', 'Q014', 'Q016', 'Q018', 'Q021', 'Q024']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
# Scaling 2 numerical features...
# Scaling complete. Active dataset has been updated.
#        TP_FAIXA_ETARIA    TP_SEXO  \
# 49534          17 anos  Masculino
# 36740          17 anos   Feminino
# 109614         18 anos  Masculino
# 40550          18 anos   Feminino
# 8599           19 anos   Feminino
# ...                ...        ...
# 12413          18 anos   Feminino
# 109663         18 anos   Feminino
# 155122         17 anos  Masculino
# 120857         18 anos   Feminino
# 60315          19 anos  Masculino
#
#                                           TP_ST_CONCLUSAO  NU_NOTA_MT  \
# 49534   Estou cursando e concluirei o Ensino Médio em ...    1.792239
# 36740   Estou cursando e concluirei o Ensino Médio apó...   -0.530709
# 109614  Estou cursando e concluirei o Ensino Médio em ...    1.488379
# 40550   Estou cursando e concluirei o Ensino Médio em ...   -1.758601
# 8599                            Já concluí o Ensino Médio   -0.658563
# ...                                                   ...         ...
# 12413   Estou cursando e concluirei o Ensino Médio em ...    0.536950
# 109663                          Já concluí o Ensino Médio    0.458079
# 155122  Estou cursando e concluirei o Ensino Médio em ...    1.794730
# 120857  Estou cursando e concluirei o Ensino Médio em ...    0.711296
# 60315                           Já concluí o Ensino Médio    0.718768
#
#         NU_NOTA_REDACAO              Q001              Q002  \
# 49534          0.811575  Faculdade ou pós       EM completo
# 36740          0.811575       EM completo  Faculdade ou pós
# 109614         0.115491       EM completo       EM completo
# 40550          1.043603     EF incompleto     EF incompleto
# 8599          -0.928634  Faculdade ou pós  Faculdade ou pós
# ...                 ...               ...               ...
# 12413         -1.392690       EM completo       EM completo
# 109663         0.231505     EF incompleto  Faculdade ou pós
# 155122         1.043603  Faculdade ou pós  Faculdade ou pós
# 120857         0.347519     EF incompleto       EM completo
# 60315          0.811575     EF incompleto     EF incompleto
#
#                                                      Q003  \
# 49534   Grupo 4: técnicos, supervisores, pequenos empr...
# 36740               Grupo 3: operários / técnicos manuais
# 109614   Grupo 5: profissões de nível superior / gestores
# 40550                 Grupo 1: ocupações rurais / básicos
# 8599                                             Não sabe
# ...                                                   ...
# 12413                 Grupo 2: serviços básicos, comércio
# 109663              Grupo 3: operários / técnicos manuais
# 155122   Grupo 5: profissões de nível superior / gestores
# 120857              Grupo 3: operários / técnicos manuais
# 60315               Grupo 3: operários / técnicos manuais
#
#                                                      Q004 Q010 Q013 Q014 Q016  \
# 49534                                            Não sabe  Sim  Sim  Sim  Sim
# 36740   Grupo 4: técnicos, supervisores, pequenos empr...  Sim  Sim  Sim  Não
# 109614                                           Não sabe  Sim  Sim  Sim  Não
# 40550                 Grupo 1: ocupações rurais / básicos  Não  Não  Sim  Não
# 8599    Grupo 4: técnicos, supervisores, pequenos empr...  Não  Não  Não  Não
# ...                                                   ...  ...  ...  ...  ...
# 12413                 Grupo 2: serviços básicos, comércio  Não  Sim  Sim  Sim
# 109663  Grupo 4: técnicos, supervisores, pequenos empr...  Não  Sim  Sim  Sim
# 155122   Grupo 5: profissões de nível superior / gestores  Sim  Não  Sim  Sim
# 120857  Grupo 4: técnicos, supervisores, pequenos empr...  Sim  Sim  Sim  Sim
# 60315                 Grupo 2: serviços básicos, comércio  Não  Sim  Sim  Sim
#
#        Q018 Q021 Q024
# 49534   Não  Não  Sim
# 36740   Não  Não  Sim
# 109614  Sim  Sim  Sim
# 40550   Não  Não  Não
# 8599    Não  Não  Sim
# ...     ...  ...  ...
# 12413   Não  Não  Não
# 109663  Não  Não  Não
# 155122  Não  Não  Sim
# 120857  Sim  Sim  Não
# 60315   Sim  Não  Sim
#
# [1776 rows x 16 columns]

# %%
evaluator.run_and_evaluate()
evaluator.plot_evaluation_metrics()
# Out:
# Running K-Prototypes for k in [2, 3, 4, 5, 6, 7, 8] and gamma in [2.0]...
# Calculating Gower distance matrix for evaluation metrics...
# Gower matrix calculation complete.
#   - Testing k=2, gamma=2.00...
#   - Testing k=3, gamma=2.00...
#   - Testing k=4, gamma=2.00...
#   - Testing k=5, gamma=2.00...
#   - Testing k=6, gamma=2.00...
#   - Testing k=7, gamma=2.00...
#   - Testing k=8, gamma=2.00...
#
# Evaluation complete.
# Plotting metrics for single gamma value

# %% [markdown]
# CV threshold: 0.15

# %%
df = pd.read_csv(r'C:\Users\jaret\OneDrive\Documents\UFG\TCC\ENEM - final\data\MICRODADOS_RJ_clean_2023.csv')
selector = FeatureSelector(df)
selector.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
# Out:
# --- FeatureSelector Initialized ---
# Detected 6 numerical columns: ['CO_MUNICIPIO_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
# Detected 29 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
#        TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA  \
# 49534          17 anos  Masculino      Branca
# 36740          17 anos   Feminino      Branca
# 109614         18 anos  Masculino      Branca
# 40550          18 anos   Feminino      Branca
# 8599           19 anos   Feminino      Branca
# ...                ...        ...         ...
# 12413          18 anos   Feminino      Branca
# 109663         18 anos   Feminino       Preta
# 155122         17 anos  Masculino      Branca
# 120857         18 anos   Feminino      Branca
# 60315          19 anos  Masculino       Parda
#
#                                           TP_ST_CONCLUSAO  NU_NOTA_CN  \
# 49534   Estou cursando e concluirei o Ensino Médio em ...       648.3
# 36740   Estou cursando e concluirei o Ensino Médio apó...       446.4
# 109614  Estou cursando e concluirei o Ensino Médio em ...       548.3
# 40550   Estou cursando e concluirei o Ensino Médio em ...       432.5
# 8599                            Já concluí o Ensino Médio       461.4
# ...                                                   ...         ...
# 12413   Estou cursando e concluirei o Ensino Médio em ...       533.8
# 109663                          Já concluí o Ensino Médio       583.8
# 155122  Estou cursando e concluirei o Ensino Médio em ...       601.9
# 120857  Estou cursando e concluirei o Ensino Médio em ...       499.8
# 60315                           Já concluí o Ensino Médio       572.9
#
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 49534        672.9       507.2       773.0            800.0  Faculdade ou pós
# 36740        515.8       519.1       493.2            800.0       EM completo
# 109614       622.3       590.8       736.4            680.0       EM completo
# 40550        458.1       446.0       345.3            840.0     EF incompleto
# 8599         541.6       550.8       477.8            500.0  Faculdade ou pós
# ...            ...         ...         ...              ...               ...
# 12413        628.6       584.0       621.8            420.0       EM completo
# 109663       635.3       661.0       612.3            700.0     EF incompleto
# 155122       554.2       544.0       773.3            840.0  Faculdade ou pós
# 120857       575.4       605.6       642.8            720.0     EF incompleto
# 60315        574.6       578.5       643.7            800.0     EF incompleto
#
#         ... Q016 Q017 Q018 Q019 Q020 Q021 Q022 Q023 Q024 Q025
# 49534   ...  Sim  Não  Não  Sim  Sim  Não  Sim  Sim  Sim  Sim
# 36740   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Sim  Sim
# 109614  ...  Não  Não  Sim  Sim  Não  Sim  Sim  Não  Sim  Sim
# 40550   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 8599    ...  Não  Não  Não  Sim  Não  Não  Sim  Sim  Sim  Sim
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 12413   ...  Sim  Não  Não  Sim  Não  Não  Sim  Sim  Não  Sim
# 109663  ...  Sim  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 155122  ...  Sim  Não  Não  Sim  Não  Não  Não  Não  Sim  Sim
# 120857  ...  Sim  Não  Sim  Sim  Sim  Sim  Sim  Sim  Não  Sim
# 60315   ...  Sim  Não  Sim  Sim  Não  Não  Sim  Não  Sim  Sim
#
# [1776 rows x 34 columns]

# %%
df_selected = selector.select_features(
    cv_threshold=0.1, 
    correlation_threshold=0.7, 
    entropy_threshold=0.7, 
    mutual_info_threshold=0.5
)
selected_features = df_selected.columns.tolist()
selected_features.append('CO_MUNICIPIO_PROVA')
# Out:
# --- Starting Feature Selection Process ---
#
# Analyzing 5 numerical features...
# Checking for Coefficient of Variation below 0.1...
#   -> No low-CV columns found.
# Checking for Pearson correlations above 0.7...
#   -> Found 1 highly-correlated columns to drop: ['NU_NOTA_CH']
#
# Checking for normalized entropy below 0.7...
#   -> Found 15 low-entropy columns to drop: ['TP_COR_RACA', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025']
# Checking for normalized mutual information above 0.5...
#   -> No high mutual information column pairs found.
#
# Dropping a total of 16 unique columns: ['Q025', 'Q008', 'Q006', 'Q011', 'NU_NOTA_CH', 'Q022', 'Q023', 'Q009', 'Q020', 'Q005', 'Q019', 'Q017', 'Q012', 'Q015', 'TP_COR_RACA', 'Q007']
# Feature selection complete.
#
# --- Feature Selection Finished ---

# %%
k_range = range(2,9)
evaluator = KPrototypesEvaluator(
    df=df[selected_features], 
    original_df_full=df,
    k_range=k_range, 
    gamma_list=[2.0],
    random_state=42
)
evaluator.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
evaluator.scale_numerical_features()
# Out:
# Full original dataframe loaded for statistical analysis.
# Detected 5 numerical columns: ['NU_NOTA_CN', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'CO_MUNICIPIO_PROVA']
# Detected 14 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q010', 'Q013', 'Q014', 'Q016', 'Q018', 'Q021', 'Q024']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
# Scaling 4 numerical features...
# Scaling complete. Active dataset has been updated.
#        TP_FAIXA_ETARIA    TP_SEXO  \
# 49534          17 anos  Masculino
# 36740          17 anos   Feminino
# 109614         18 anos  Masculino
# 40550          18 anos   Feminino
# 8599           19 anos   Feminino
# ...                ...        ...
# 12413          18 anos   Feminino
# 109663         18 anos   Feminino
# 155122         17 anos  Masculino
# 120857         18 anos   Feminino
# 60315          19 anos  Masculino
#
#                                           TP_ST_CONCLUSAO  NU_NOTA_CN  \
# 49534   Estou cursando e concluirei o Ensino Médio em ...    1.859715
# 36740   Estou cursando e concluirei o Ensino Médio apó...   -0.808010
# 109614  Estou cursando e concluirei o Ensino Médio em ...    0.538405
# 40550   Estou cursando e concluirei o Ensino Médio em ...   -0.991672
# 8599                            Já concluí o Ensino Médio   -0.609814
# ...                                                   ...         ...
# 12413   Estou cursando e concluirei o Ensino Médio em ...    0.346815
# 109663                          Já concluí o Ensino Médio    1.007470
# 155122  Estou cursando e concluirei o Ensino Médio em ...    1.246627
# 120857  Estou cursando e concluirei o Ensino Médio em ...   -0.102431
# 60315                           Já concluí o Ensino Médio    0.863447
#
#         NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 49534    -0.402974    1.792239         0.811575  Faculdade ou pós
# 36740    -0.231251   -0.530709         0.811575       EM completo
# 109614    0.803416    1.488379         0.115491       EM completo
# 40550    -1.286121   -1.758601         1.043603     EF incompleto
# 8599      0.226196   -0.658563        -0.928634  Faculdade ou pós
# ...            ...         ...              ...               ...
# 12413     0.705289    0.536950        -1.392690       EM completo
# 109663    1.816438    0.458079         0.231505     EF incompleto
# 155122    0.128068    1.794730         1.043603  Faculdade ou pós
# 120857    1.016988    0.711296         0.347519     EF incompleto
# 60315     0.625921    0.718768         0.811575     EF incompleto
#
#                     Q002                                               Q003  \
# 49534        EM completo  Grupo 4: técnicos, supervisores, pequenos empr...
# 36740   Faculdade ou pós              Grupo 3: operários / técnicos manuais
# 109614       EM completo   Grupo 5: profissões de nível superior / gestores
# 40550      EF incompleto                Grupo 1: ocupações rurais / básicos
# 8599    Faculdade ou pós                                           Não sabe
# ...                  ...                                                ...
# 12413        EM completo                Grupo 2: serviços básicos, comércio
# 109663  Faculdade ou pós              Grupo 3: operários / técnicos manuais
# 155122  Faculdade ou pós   Grupo 5: profissões de nível superior / gestores
# 120857       EM completo              Grupo 3: operários / técnicos manuais
# 60315      EF incompleto              Grupo 3: operários / técnicos manuais
#
#                                                      Q004 Q010 Q013 Q014 Q016  \
# 49534                                            Não sabe  Sim  Sim  Sim  Sim
# 36740   Grupo 4: técnicos, supervisores, pequenos empr...  Sim  Sim  Sim  Não
# 109614                                           Não sabe  Sim  Sim  Sim  Não
# 40550                 Grupo 1: ocupações rurais / básicos  Não  Não  Sim  Não
# 8599    Grupo 4: técnicos, supervisores, pequenos empr...  Não  Não  Não  Não
# ...                                                   ...  ...  ...  ...  ...
# 12413                 Grupo 2: serviços básicos, comércio  Não  Sim  Sim  Sim
# 109663  Grupo 4: técnicos, supervisores, pequenos empr...  Não  Sim  Sim  Sim
# 155122   Grupo 5: profissões de nível superior / gestores  Sim  Não  Sim  Sim
# 120857  Grupo 4: técnicos, supervisores, pequenos empr...  Sim  Sim  Sim  Sim
# 60315                 Grupo 2: serviços básicos, comércio  Não  Sim  Sim  Sim
#
#        Q018 Q021 Q024
# 49534   Não  Não  Sim
# 36740   Não  Não  Sim
# 109614  Sim  Sim  Sim
# 40550   Não  Não  Não
# 8599    Não  Não  Sim
# ...     ...  ...  ...
# 12413   Não  Não  Não
# 109663  Não  Não  Não
# 155122  Não  Não  Sim
# 120857  Sim  Sim  Não
# 60315   Sim  Não  Sim
#
# [1776 rows x 18 columns]

# %%
evaluator.run_and_evaluate()
evaluator.plot_evaluation_metrics()
# Out:
# Running K-Prototypes for k in [2, 3, 4, 5, 6, 7, 8] and gamma in [2.0]...
# Calculating Gower distance matrix for evaluation metrics...
# Gower matrix calculation complete.
#   - Testing k=2, gamma=2.00...
#   - Testing k=3, gamma=2.00...
#   - Testing k=4, gamma=2.00...
#   - Testing k=5, gamma=2.00...
#   - Testing k=6, gamma=2.00...
#   - Testing k=7, gamma=2.00...
#   - Testing k=8, gamma=2.00...
#
# Evaluation complete.
# Plotting metrics for single gamma value

# %% [markdown]
# Entropy threshold: 0.7

# %%
df = pd.read_csv(r'C:\Users\jaret\OneDrive\Documents\UFG\TCC\ENEM - final\data\MICRODADOS_RJ_clean_2023.csv')
selector = FeatureSelector(df)
selector.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
# Out:
# --- FeatureSelector Initialized ---
# Detected 6 numerical columns: ['CO_MUNICIPIO_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
# Detected 29 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
#        TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA  \
# 49534          17 anos  Masculino      Branca
# 36740          17 anos   Feminino      Branca
# 109614         18 anos  Masculino      Branca
# 40550          18 anos   Feminino      Branca
# 8599           19 anos   Feminino      Branca
# ...                ...        ...         ...
# 12413          18 anos   Feminino      Branca
# 109663         18 anos   Feminino       Preta
# 155122         17 anos  Masculino      Branca
# 120857         18 anos   Feminino      Branca
# 60315          19 anos  Masculino       Parda
#
#                                           TP_ST_CONCLUSAO  NU_NOTA_CN  \
# 49534   Estou cursando e concluirei o Ensino Médio em ...       648.3
# 36740   Estou cursando e concluirei o Ensino Médio apó...       446.4
# 109614  Estou cursando e concluirei o Ensino Médio em ...       548.3
# 40550   Estou cursando e concluirei o Ensino Médio em ...       432.5
# 8599                            Já concluí o Ensino Médio       461.4
# ...                                                   ...         ...
# 12413   Estou cursando e concluirei o Ensino Médio em ...       533.8
# 109663                          Já concluí o Ensino Médio       583.8
# 155122  Estou cursando e concluirei o Ensino Médio em ...       601.9
# 120857  Estou cursando e concluirei o Ensino Médio em ...       499.8
# 60315                           Já concluí o Ensino Médio       572.9
#
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 49534        672.9       507.2       773.0            800.0  Faculdade ou pós
# 36740        515.8       519.1       493.2            800.0       EM completo
# 109614       622.3       590.8       736.4            680.0       EM completo
# 40550        458.1       446.0       345.3            840.0     EF incompleto
# 8599         541.6       550.8       477.8            500.0  Faculdade ou pós
# ...            ...         ...         ...              ...               ...
# 12413        628.6       584.0       621.8            420.0       EM completo
# 109663       635.3       661.0       612.3            700.0     EF incompleto
# 155122       554.2       544.0       773.3            840.0  Faculdade ou pós
# 120857       575.4       605.6       642.8            720.0     EF incompleto
# 60315        574.6       578.5       643.7            800.0     EF incompleto
#
#         ... Q016 Q017 Q018 Q019 Q020 Q021 Q022 Q023 Q024 Q025
# 49534   ...  Sim  Não  Não  Sim  Sim  Não  Sim  Sim  Sim  Sim
# 36740   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Sim  Sim
# 109614  ...  Não  Não  Sim  Sim  Não  Sim  Sim  Não  Sim  Sim
# 40550   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 8599    ...  Não  Não  Não  Sim  Não  Não  Sim  Sim  Sim  Sim
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 12413   ...  Sim  Não  Não  Sim  Não  Não  Sim  Sim  Não  Sim
# 109663  ...  Sim  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 155122  ...  Sim  Não  Não  Sim  Não  Não  Não  Não  Sim  Sim
# 120857  ...  Sim  Não  Sim  Sim  Sim  Sim  Sim  Sim  Não  Sim
# 60315   ...  Sim  Não  Sim  Sim  Não  Não  Sim  Não  Sim  Sim
#
# [1776 rows x 34 columns]

# %%
df_selected = selector.select_features(
    cv_threshold=0.2, 
    correlation_threshold=0.7, 
    entropy_threshold=0.8, 
    mutual_info_threshold=0.5
)
selected_features = df_selected.columns.tolist()
selected_features.append('CO_MUNICIPIO_PROVA')
# Out:
# --- Starting Feature Selection Process ---
#
# Analyzing 5 numerical features...
# Checking for Coefficient of Variation below 0.2...
#   -> Found 3 low-CV columns to drop: ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']
# Checking for Pearson correlations above 0.7...
#   -> No highly correlated column pairs found.
#
# Checking for normalized entropy below 0.8...
#   -> Found 18 low-entropy columns to drop: ['TP_FAIXA_ETARIA', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q014', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025']
# Checking for normalized mutual information above 0.5...
#   -> No high mutual information column pairs found.
#
# Dropping a total of 21 unique columns: ['TP_ST_CONCLUSAO', 'Q009', 'Q025', 'Q017', 'Q012', 'Q015', 'Q007', 'NU_NOTA_CH', 'Q020', 'Q014', 'Q019', 'Q006', 'Q023', 'Q022', 'TP_COR_RACA', 'NU_NOTA_LC', 'Q008', 'Q011', 'NU_NOTA_CN', 'Q005', 'TP_FAIXA_ETARIA']
# Feature selection complete.
#
# --- Feature Selection Finished ---

# %%
k_range = range(2,9)
evaluator = KPrototypesEvaluator(
    df=df[selected_features], 
    original_df_full=df,
    k_range=k_range, 
    gamma_list=[2.0],
    random_state=42
)
evaluator.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
evaluator.scale_numerical_features()
# Out:
# Full original dataframe loaded for statistical analysis.
# Detected 3 numerical columns: ['NU_NOTA_MT', 'NU_NOTA_REDACAO', 'CO_MUNICIPIO_PROVA']
# Detected 11 categorical columns: ['TP_SEXO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q010', 'Q013', 'Q016', 'Q018', 'Q021', 'Q024']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
# Scaling 2 numerical features...
# Scaling complete. Active dataset has been updated.
#           TP_SEXO  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 49534   Masculino    1.792239         0.811575  Faculdade ou pós
# 36740    Feminino   -0.530709         0.811575       EM completo
# 109614  Masculino    1.488379         0.115491       EM completo
# 40550    Feminino   -1.758601         1.043603     EF incompleto
# 8599     Feminino   -0.658563        -0.928634  Faculdade ou pós
# ...           ...         ...              ...               ...
# 12413    Feminino    0.536950        -1.392690       EM completo
# 109663   Feminino    0.458079         0.231505     EF incompleto
# 155122  Masculino    1.794730         1.043603  Faculdade ou pós
# 120857   Feminino    0.711296         0.347519     EF incompleto
# 60315   Masculino    0.718768         0.811575     EF incompleto
#
#                     Q002                                               Q003  \
# 49534        EM completo  Grupo 4: técnicos, supervisores, pequenos empr...
# 36740   Faculdade ou pós              Grupo 3: operários / técnicos manuais
# 109614       EM completo   Grupo 5: profissões de nível superior / gestores
# 40550      EF incompleto                Grupo 1: ocupações rurais / básicos
# 8599    Faculdade ou pós                                           Não sabe
# ...                  ...                                                ...
# 12413        EM completo                Grupo 2: serviços básicos, comércio
# 109663  Faculdade ou pós              Grupo 3: operários / técnicos manuais
# 155122  Faculdade ou pós   Grupo 5: profissões de nível superior / gestores
# 120857       EM completo              Grupo 3: operários / técnicos manuais
# 60315      EF incompleto              Grupo 3: operários / técnicos manuais
#
#                                                      Q004 Q010 Q013 Q016 Q018  \
# 49534                                            Não sabe  Sim  Sim  Sim  Não
# 36740   Grupo 4: técnicos, supervisores, pequenos empr...  Sim  Sim  Não  Não
# 109614                                           Não sabe  Sim  Sim  Não  Sim
# 40550                 Grupo 1: ocupações rurais / básicos  Não  Não  Não  Não
# 8599    Grupo 4: técnicos, supervisores, pequenos empr...  Não  Não  Não  Não
# ...                                                   ...  ...  ...  ...  ...
# 12413                 Grupo 2: serviços básicos, comércio  Não  Sim  Sim  Não
# 109663  Grupo 4: técnicos, supervisores, pequenos empr...  Não  Sim  Sim  Não
# 155122   Grupo 5: profissões de nível superior / gestores  Sim  Não  Sim  Não
# 120857  Grupo 4: técnicos, supervisores, pequenos empr...  Sim  Sim  Sim  Sim
# 60315                 Grupo 2: serviços básicos, comércio  Não  Sim  Sim  Sim
#
#        Q021 Q024
# 49534   Não  Sim
# 36740   Não  Sim
# 109614  Sim  Sim
# 40550   Não  Não
# 8599    Não  Sim
# ...     ...  ...
# 12413   Não  Não
# 109663  Não  Não
# 155122  Não  Sim
# 120857  Sim  Não
# 60315   Não  Sim
#
# [1776 rows x 13 columns]

# %%
evaluator.run_and_evaluate()
evaluator.plot_evaluation_metrics()
# Out:
# Running K-Prototypes for k in [2, 3, 4, 5, 6, 7, 8] and gamma in [2.0]...
# Calculating Gower distance matrix for evaluation metrics...
# Gower matrix calculation complete.
#   - Testing k=2, gamma=2.00...
#   - Testing k=3, gamma=2.00...
#   - Testing k=4, gamma=2.00...
#   - Testing k=5, gamma=2.00...
#   - Testing k=6, gamma=2.00...
#   - Testing k=7, gamma=2.00...
#   - Testing k=8, gamma=2.00...
#
# Evaluation complete.
# Plotting metrics for single gamma value

# %% [markdown]
# Entropy threshold: 0.6

# %%
df = pd.read_csv(r'C:\Users\jaret\OneDrive\Documents\UFG\TCC\ENEM - final\data\MICRODADOS_RJ_clean_2023.csv')
selector = FeatureSelector(df)
selector.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
# Out:
# --- FeatureSelector Initialized ---
# Detected 6 numerical columns: ['CO_MUNICIPIO_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
# Detected 29 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
#        TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA  \
# 49534          17 anos  Masculino      Branca
# 36740          17 anos   Feminino      Branca
# 109614         18 anos  Masculino      Branca
# 40550          18 anos   Feminino      Branca
# 8599           19 anos   Feminino      Branca
# ...                ...        ...         ...
# 12413          18 anos   Feminino      Branca
# 109663         18 anos   Feminino       Preta
# 155122         17 anos  Masculino      Branca
# 120857         18 anos   Feminino      Branca
# 60315          19 anos  Masculino       Parda
#
#                                           TP_ST_CONCLUSAO  NU_NOTA_CN  \
# 49534   Estou cursando e concluirei o Ensino Médio em ...       648.3
# 36740   Estou cursando e concluirei o Ensino Médio apó...       446.4
# 109614  Estou cursando e concluirei o Ensino Médio em ...       548.3
# 40550   Estou cursando e concluirei o Ensino Médio em ...       432.5
# 8599                            Já concluí o Ensino Médio       461.4
# ...                                                   ...         ...
# 12413   Estou cursando e concluirei o Ensino Médio em ...       533.8
# 109663                          Já concluí o Ensino Médio       583.8
# 155122  Estou cursando e concluirei o Ensino Médio em ...       601.9
# 120857  Estou cursando e concluirei o Ensino Médio em ...       499.8
# 60315                           Já concluí o Ensino Médio       572.9
#
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO              Q001  \
# 49534        672.9       507.2       773.0            800.0  Faculdade ou pós
# 36740        515.8       519.1       493.2            800.0       EM completo
# 109614       622.3       590.8       736.4            680.0       EM completo
# 40550        458.1       446.0       345.3            840.0     EF incompleto
# 8599         541.6       550.8       477.8            500.0  Faculdade ou pós
# ...            ...         ...         ...              ...               ...
# 12413        628.6       584.0       621.8            420.0       EM completo
# 109663       635.3       661.0       612.3            700.0     EF incompleto
# 155122       554.2       544.0       773.3            840.0  Faculdade ou pós
# 120857       575.4       605.6       642.8            720.0     EF incompleto
# 60315        574.6       578.5       643.7            800.0     EF incompleto
#
#         ... Q016 Q017 Q018 Q019 Q020 Q021 Q022 Q023 Q024 Q025
# 49534   ...  Sim  Não  Não  Sim  Sim  Não  Sim  Sim  Sim  Sim
# 36740   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Sim  Sim
# 109614  ...  Não  Não  Sim  Sim  Não  Sim  Sim  Não  Sim  Sim
# 40550   ...  Não  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 8599    ...  Não  Não  Não  Sim  Não  Não  Sim  Sim  Sim  Sim
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 12413   ...  Sim  Não  Não  Sim  Não  Não  Sim  Sim  Não  Sim
# 109663  ...  Sim  Não  Não  Sim  Não  Não  Sim  Não  Não  Sim
# 155122  ...  Sim  Não  Não  Sim  Não  Não  Não  Não  Sim  Sim
# 120857  ...  Sim  Não  Sim  Sim  Sim  Sim  Sim  Sim  Não  Sim
# 60315   ...  Sim  Não  Sim  Sim  Não  Não  Sim  Não  Sim  Sim
#
# [1776 rows x 34 columns]

# %%
df_selected = selector.select_features(
    cv_threshold=0.2, 
    correlation_threshold=0.7, 
    entropy_threshold=0.6, 
    mutual_info_threshold=0.5
)
selected_features = df_selected.columns.tolist()
selected_features.append('CO_MUNICIPIO_PROVA')
# Out:
# --- Starting Feature Selection Process ---
#
# Analyzing 5 numerical features...
# Checking for Coefficient of Variation below 0.2...
#   -> Found 3 low-CV columns to drop: ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']
# Checking for Pearson correlations above 0.7...
#   -> No highly correlated column pairs found.
#
# Checking for normalized entropy below 0.6...
#   -> Found 11 low-entropy columns to drop: ['Q005', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q015', 'Q017', 'Q019', 'Q022', 'Q025']
# Checking for normalized mutual information above 0.5...
#   -> No high mutual information column pairs found.
#
# Dropping a total of 14 unique columns: ['Q025', 'NU_NOTA_LC', 'Q008', 'Q011', 'NU_NOTA_CH', 'Q022', 'Q009', 'NU_NOTA_CN', 'Q005', 'Q019', 'Q017', 'Q012', 'Q015', 'Q007']
# Feature selection complete.
#
# --- Feature Selection Finished ---

# %%
k_range = range(2,9)
evaluator = KPrototypesEvaluator(
    df=df[selected_features], 
    original_df_full=df,
    k_range=k_range, 
    gamma_list=[2.0],
    random_state=42
)
evaluator.stratified_sample(
    strata_col="CO_MUNICIPIO_PROVA", 
    sample_frac=0.01
)
evaluator.scale_numerical_features()
# Out:
# Full original dataframe loaded for statistical analysis.
# Detected 3 numerical columns: ['NU_NOTA_MT', 'NU_NOTA_REDACAO', 'CO_MUNICIPIO_PROVA']
# Detected 18 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q010', 'Q013', 'Q014', 'Q016', 'Q018', 'Q020', 'Q021', 'Q023', 'Q024']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 1.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 1776 rows.
# Scaling 2 numerical features...
# Scaling complete. Active dataset has been updated.
#        TP_FAIXA_ETARIA    TP_SEXO TP_COR_RACA  \
# 49534          17 anos  Masculino      Branca
# 36740          17 anos   Feminino      Branca
# 109614         18 anos  Masculino      Branca
# 40550          18 anos   Feminino      Branca
# 8599           19 anos   Feminino      Branca
# ...                ...        ...         ...
# 12413          18 anos   Feminino      Branca
# 109663         18 anos   Feminino       Preta
# 155122         17 anos  Masculino      Branca
# 120857         18 anos   Feminino      Branca
# 60315          19 anos  Masculino       Parda
#
#                                           TP_ST_CONCLUSAO  NU_NOTA_MT  \
# 49534   Estou cursando e concluirei o Ensino Médio em ...    1.792239
# 36740   Estou cursando e concluirei o Ensino Médio apó...   -0.530709
# 109614  Estou cursando e concluirei o Ensino Médio em ...    1.488379
# 40550   Estou cursando e concluirei o Ensino Médio em ...   -1.758601
# 8599                            Já concluí o Ensino Médio   -0.658563
# ...                                                   ...         ...
# 12413   Estou cursando e concluirei o Ensino Médio em ...    0.536950
# 109663                          Já concluí o Ensino Médio    0.458079
# 155122  Estou cursando e concluirei o Ensino Médio em ...    1.794730
# 120857  Estou cursando e concluirei o Ensino Médio em ...    0.711296
# 60315                           Já concluí o Ensino Médio    0.718768
#
#         NU_NOTA_REDACAO              Q001              Q002  \
# 49534          0.811575  Faculdade ou pós       EM completo
# 36740          0.811575       EM completo  Faculdade ou pós
# 109614         0.115491       EM completo       EM completo
# 40550          1.043603     EF incompleto     EF incompleto
# 8599          -0.928634  Faculdade ou pós  Faculdade ou pós
# ...                 ...               ...               ...
# 12413         -1.392690       EM completo       EM completo
# 109663         0.231505     EF incompleto  Faculdade ou pós
# 155122         1.043603  Faculdade ou pós  Faculdade ou pós
# 120857         0.347519     EF incompleto       EM completo
# 60315          0.811575     EF incompleto     EF incompleto
#
#                                                      Q003  \
# 49534   Grupo 4: técnicos, supervisores, pequenos empr...
# 36740               Grupo 3: operários / técnicos manuais
# 109614   Grupo 5: profissões de nível superior / gestores
# 40550                 Grupo 1: ocupações rurais / básicos
# 8599                                             Não sabe
# ...                                                   ...
# 12413                 Grupo 2: serviços básicos, comércio
# 109663              Grupo 3: operários / técnicos manuais
# 155122   Grupo 5: profissões de nível superior / gestores
# 120857              Grupo 3: operários / técnicos manuais
# 60315               Grupo 3: operários / técnicos manuais
#
#                                                      Q004        Q006 Q010  \
# 49534                                            Não sabe    4 a 6 SM  Sim
# 36740   Grupo 4: técnicos, supervisores, pequenos empr...    4 a 6 SM  Sim
# 109614                                           Não sabe  10 a 15 SM  Sim
# 40550                 Grupo 1: ocupações rurais / básicos    Até 2 SM  Não
# 8599    Grupo 4: técnicos, supervisores, pequenos empr...    Até 2 SM  Não
# ...                                                   ...         ...  ...
# 12413                 Grupo 2: serviços básicos, comércio    2 a 4 SM  Não
# 109663  Grupo 4: técnicos, supervisores, pequenos empr...    Até 2 SM  Não
# 155122   Grupo 5: profissões de nível superior / gestores    4 a 6 SM  Sim
# 120857  Grupo 4: técnicos, supervisores, pequenos empr...    2 a 4 SM  Sim
# 60315                 Grupo 2: serviços básicos, comércio    Até 2 SM  Não
#
#        Q013 Q014 Q016 Q018 Q020 Q021 Q023 Q024
# 49534   Sim  Sim  Sim  Não  Sim  Não  Sim  Sim
# 36740   Sim  Sim  Não  Não  Não  Não  Não  Sim
# 109614  Sim  Sim  Não  Sim  Não  Sim  Não  Sim
# 40550   Não  Sim  Não  Não  Não  Não  Não  Não
# 8599    Não  Não  Não  Não  Não  Não  Sim  Sim
# ...     ...  ...  ...  ...  ...  ...  ...  ...
# 12413   Sim  Sim  Sim  Não  Não  Não  Sim  Não
# 109663  Sim  Sim  Sim  Não  Não  Não  Não  Não
# 155122  Não  Sim  Sim  Não  Não  Não  Não  Sim
# 120857  Sim  Sim  Sim  Sim  Sim  Sim  Sim  Não
# 60315   Sim  Sim  Sim  Sim  Não  Não  Não  Sim
#
# [1776 rows x 20 columns]

# %%
evaluator.run_and_evaluate()
evaluator.plot_evaluation_metrics()
# Out:
# Running K-Prototypes for k in [2, 3, 4, 5, 6, 7, 8] and gamma in [2.0]...
# Calculating Gower distance matrix for evaluation metrics...
# Gower matrix calculation complete.
#   - Testing k=2, gamma=2.00...
#   - Testing k=3, gamma=2.00...
#   - Testing k=4, gamma=2.00...
#   - Testing k=5, gamma=2.00...
#   - Testing k=6, gamma=2.00...
#   - Testing k=7, gamma=2.00...
#   - Testing k=8, gamma=2.00...
#
# Evaluation complete.
# Plotting metrics for single gamma value
