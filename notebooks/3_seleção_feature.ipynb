# %%
import sys
import os
import pandas as pd 

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from scripts.clustering.feature_selection import FeatureSelector

# %%
df_original = pd.read_csv('C:/Users/jaret/OneDrive/Documents/UFG/TCC/ENEM - final/data/MICRODADOS_RJ_clean_2023.csv')

# %%
selector = FeatureSelector(df_original)
selector.stratified_sample(strata_col='CO_MUNICIPIO_PROVA', sample_frac=0.2)
selector.analyze_features()
# Out:
# --- FeatureSelector Initialized ---
# Detected 6 numerical columns: ['CO_MUNICIPIO_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
# Detected 29 categorical columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025']
# Performing stratified sampling on 'CO_MUNICIPIO_PROVA' with a 20.00% fraction...
# Sampling complete. Active dataset reduced from 177828 to 35566 rows.
#
# --- Starting Feature Analysis ---
# Calculating Coefficient of Variation for numerical features...
# Calculating Correlation Matrix for numerical features...
# Calculating Normalized Entropy for categorical features...
# Calculating Normalized Mutual Information for categorical features...

# %%
keep, remove = selector.select_features(
    cv_min=0.2,    
    entropy_min=0.9
)

keep
# Out:
# --- Starting Feature Selection Process ---
# Checking for numerical features with CV < 0.2...
#   -> Found 3 features with low CV: ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']
# Checking for categorical features with Normalized Entropy < 0.9...
#   -> Found 20 features with low entropy: ['TP_FAIXA_ETARIA', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q002', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q014', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025']
#
# --- Feature Selection Complete ---
# Total features to remove: 23
# Features to remove: ['NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_LC', 'Q002', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q014', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025', 'TP_COR_RACA', 'TP_FAIXA_ETARIA', 'TP_ST_CONCLUSAO']
# Total features to keep: 11
# Features to keep: ['NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q003', 'Q010', 'Q013', 'Q016', 'Q018', 'Q021', 'Q024', 'TP_SEXO']
# ['NU_NOTA_MT',
#  'NU_NOTA_REDACAO',
# ...

# %%
keep, remove = selector.select_features(
    cv_min=0.2,    
    entropy_min=0.8
)

keep
# Out:
# --- Starting Feature Selection Process ---
# Checking for numerical features with CV < 0.2...
#   -> Found 3 features with low CV: ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']
# Checking for categorical features with Normalized Entropy < 0.8...
#   -> Found 19 features with low entropy: ['TP_FAIXA_ETARIA', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q014', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025']
#
# --- Feature Selection Complete ---
# Total features to remove: 22
# Features to remove: ['NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_LC', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q014', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025', 'TP_COR_RACA', 'TP_FAIXA_ETARIA', 'TP_ST_CONCLUSAO']
# Total features to keep: 12
# Features to keep: ['NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q010', 'Q013', 'Q016', 'Q018', 'Q021', 'Q024', 'TP_SEXO']
# ['NU_NOTA_MT',
#  'NU_NOTA_REDACAO',
# ...

# %%
keep, remove = selector.select_features(
    cv_min=0.2,    
    entropy_min=0.7
)

keep
# Out:
# --- Starting Feature Selection Process ---
# Checking for numerical features with CV < 0.2...
#   -> Found 3 features with low CV: ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']
# Checking for categorical features with Normalized Entropy < 0.7...
#   -> Found 14 features with low entropy: ['TP_COR_RACA', 'Q005', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025']
#
# --- Feature Selection Complete ---
# Total features to remove: 17
# Features to remove: ['NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_LC', 'Q005', 'Q007', 'Q008', 'Q009', 'Q011', 'Q012', 'Q015', 'Q017', 'Q019', 'Q020', 'Q022', 'Q023', 'Q025', 'TP_COR_RACA']
# Total features to keep: 17
# Features to keep: ['NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q006', 'Q010', 'Q013', 'Q014', 'Q016', 'Q018', 'Q021', 'Q024', 'TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ST_CONCLUSAO']
# ['NU_NOTA_MT',
#  'NU_NOTA_REDACAO',
#  'Q001',
#  'Q002',
#  'Q003',
#  'Q004',
#  'Q006',
#  'Q010',
# ...
